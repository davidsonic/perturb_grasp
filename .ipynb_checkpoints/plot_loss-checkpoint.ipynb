# %%
# visualization of loss curve
from baselines.common import plot_util as pu
results = pu.load_results('/tmp/gym/ppo_1_inverted_pendulum/')

# %%
import matplotlib.pyplot as plt
import numpy as np
r = results[0]
plt.plot(np.cumsum(r.monitor.l), r.monitor.r)

# %%
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

# %%
# visualization of loss curve
from baselines.common import plot_util as pu
results = pu.load_results('/tmp/gym/ppo_1_inverted_pendulum_seeds/'); print(len(results))
# Out:
# 21

# %%
pu.plot_results(results)
# Out:
# (<Figure size 432x2592 with 6 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efb27ffaef0>],
# ...
#        dtype=object))

# %%
pu.plot_results(results, average_group=True, shaded_std=False)
# Out:
# (<Figure size 432x2592 with 6 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efb25e07438>],
# ...
#        dtype=object))

# %%
pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# (<Figure size 432x432 with 1 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efb24404ba8>]],
#        dtype=object))

# %%
# Baseline training
# !for seed in $(seq 0 3); do DISPLAY=:8 vglrun -d :7.0 python reimplementation/run_mujoco_ppo.py --seed=$seed --prefix='c-' --log_dir='/tmp/gym/ppo_1_inverted_pendulum_seeds'; done
# Out:
# --------------------------------------------------------------------------
# [[7699,1],0]: A high-performance Open MPI point-to-point messaging module
# was unable to find any relevant network interfaces:
#
# Module: OpenFabrics (openib)
#   Host: usc-c1
#
# Another transport will be used instead, although this may result in
# lower performance.
# --------------------------------------------------------------------------
# Logging to /mnt/jiali/reinforce-exp/baselines/tensorboard_logs
# cymj load_cython_ext finished
# Training params
# Namespace(apply_random=False, env='MyInvertedPendulum-v2', log_dir='/tmp/gym/ppo_1_inverted_pendulum_seeds', prefix='c-', seed=0, sr=1000.0)
# log_dir is located at:  /tmp/gym/ppo_1_inverted_pendulum_seeds/c-0
# 2019-01-04 09:38:43.511384: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# ...

# %%
# Learn with perturbation
# !for seed in $(seq 0 0); do DISPLAY=:8 vglrun -d :7.0 python reimplementation/run_mujoco_ppo.py  --seed=$seed --nums=1000 --prefix='rand2-' --apply_random=True --coeff=0.8 --log_dir='/tmp/gym/ppo_1_inverted_pendulum_seeds'; done
# Out:
# --------------------------------------------------------------------------
# [[26698,1],0]: A high-performance Open MPI point-to-point messaging module
# was unable to find any relevant network interfaces:
#
# Module: OpenFabrics (openib)
#   Host: usc-c1
#
# Another transport will be used instead, although this may result in
# lower performance.
# --------------------------------------------------------------------------
# Logging to /mnt/jiali/reinforce-exp/baselines/tensorboard_logs
# cymj load_cython_ext finished
# Training params
# Namespace(apply_random='True', coeff=0.8, env='MyInvertedPendulum-v2', log_dir='/tmp/gym/ppo_1_inverted_pendulum_seeds', nums=1000, prefix='rand2-', seed=0, sr=1000.0)
# log_dir is located at:  /tmp/gym/ppo_1_inverted_pendulum_seeds/rand2-0
# 2019-01-04 11:59:26.802005: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# ...
